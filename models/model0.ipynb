# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from data.data_helpers import FullDataFrame

df = FullDataFrame
print(df.to_string())
# Out:
# Requesting 2018, chunk 1 → era5_tehachapi_2018_H1.nc
# 2025-11-19 16:09:48,090 INFO Request ID is 816f681a-2cd7-4993-83a1-b374b53cc66b
# 2025-11-19 16:09:48,227 INFO status has been updated to accepted
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 import os
#       3 sys.path.append(os.path.abspath(".."))
# ----> 4 from data.data_helpers import FullDataFrame
#       6 df = FullDataFrame
#       7 print(df.to_string())
#
# File c:\Users\Michel\OneDrive\Projects\cis5200-project\data\data_helpers.py:178
#     173     df.set_index('datetime', inplace=True)
#     176     return df
# --> 178 FullDataFrame = get_dataframe()
#
# File c:\Users\Michel\OneDrive\Projects\cis5200-project\data\data_helpers.py:155, in get_dataframe(dataset, variables, years, month_groups, days, hours)
#     144 def get_dataframe(
# ...
