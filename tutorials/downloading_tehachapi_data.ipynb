# %%
import sys
import os

# add project root to Python path
sys.path.append(os.path.abspath(".."))

from data.data_helpers import load_data, combine_nc_files

# %%
all_targets = load_data()
ds = combine_nc_files(all_targets)
print(ds)
# Out:
# Requesting 2018, chunk 1 → era5_tehachapi_2018_H1.nc
# 2025-11-14 11:00:03,949 INFO Request ID is 86a0296c-5a56-49e4-8993-0ea6f608046a
# 2025-11-14 11:00:04,089 INFO status has been updated to accepted
# 2025-11-14 11:00:18,601 INFO status has been updated to running
# 2025-11-14 11:16:27,704 INFO status has been updated to successful
# 668b39958034e602249bd324ce3e44c3.nc:   0%|          | 0.00/393k [00:00<?, ?B/s]
# Requesting 2018, chunk 2 → era5_tehachapi_2018_H2.nc
# 2025-11-14 11:16:29,953 INFO Request ID is 4da33230-af39-476d-b6b7-9b8da2578231
# 2025-11-14 11:16:30,096 INFO status has been updated to accepted
# 2025-11-14 11:16:44,034 INFO status has been updated to running
# 2025-11-14 11:32:52,930 INFO status has been updated to successful
# fc2e3246d34c59ef2c471ec7d15f5438.nc:   0%|          | 0.00/395k [00:00<?, ?B/s]
# Requesting 2019, chunk 1 → era5_tehachapi_2019_H1.nc
# 2025-11-14 11:32:57,189 INFO Request ID is 07ebd880-5eba-4025-b9a1-232bafd583fa
# 2025-11-14 11:32:58,372 INFO status has been updated to accepted
# 2025-11-14 11:33:12,242 INFO status has been updated to running
# 2025-11-14 11:57:23,783 INFO status has been updated to successful
# c25f36b799249d5bbfb1c0ec68fee43.nc:   0%|          | 0.00/393k [00:00<?, ?B/s]
# Requesting 2019, chunk 2 → era5_tehachapi_2019_H2.nc
# 2025-11-14 11:57:26,210 INFO Request ID is 39f47cef-35ee-43d6-b840-aa1f4b398227
# 2025-11-14 11:57:26,351 INFO status has been updated to accepted
# 2025-11-14 11:58:17,992 INFO status has been updated to running
# 2025-11-14 12:11:52,307 INFO status has been updated to successful
# 9e5f8f357338b63c6449291dd99586a4.nc:   0%|          | 0.00/395k [00:00<?, ?B/s]
# Requesting 2020, chunk 1 → era5_tehachapi_2020_H1.nc
# 2025-11-14 12:11:55,383 INFO Request ID is 38610e65-929d-4495-9e3a-35e8c2fffc03
# 2025-11-14 12:11:55,581 INFO status has been updated to accepted
# 2025-11-14 12:13:50,880 INFO status has been updated to running
# 2025-11-14 12:28:18,959 INFO status has been updated to successful
# 908b7435a2e66c735bbc380efdb3bc8.nc:   0%|          | 0.00/394k [00:00<?, ?B/s]
# Requesting 2020, chunk 2 → era5_tehachapi_2020_H2.nc
# 2025-11-14 12:28:21,666 INFO Request ID is a49c8f8c-a4ba-4b8c-913d-e54a662e1df0
# 2025-11-14 12:28:21,801 INFO status has been updated to accepted
# 2025-11-14 12:28:36,719 INFO status has been updated to running
# 2025-11-14 12:42:45,458 INFO status has been updated to successful
# 65889b0b1acd713660e544998b20d2b5.nc:   0%|          | 0.00/395k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 all_targets = load_data()
# ----> 2 ds = combine_nc_files(all_targets)
#       3 print(ds)
#
# File c:\Users\Michel\OneDrive\Projects\cis5200-project\data\data_helpers.py:126, in combine_nc_files(targets)
#     123 if not paths:
#     124     raise ValueError("No existing NetCDF files found in targets.")
# --> 126 ds = xr.open_mfdataset(
#     127     paths,
#     128     combine="by_coords",   # align by valid_time / lat / lon
#     129     engine="netcdf4",      # explicit is nice but optional
#     130 )
#     131 return ds
#
# File c:\Users\Michel\AppData\Local\Programs\Python\Python313\Lib\site-packages\xarray\backends\api.py:1691, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1688     open_ = open_dataset
#    1689     getattr_ = getattr
# -> 1691 datasets = [open_(p, **open_kwargs) for p in paths1d]
#    1692 closers = [getattr_(ds, "_close") for ds in datasets]
#    1693 if preprocess is not None:
#
# File c:\Users\Michel\AppData\Local\Programs\Python\Python313\Lib\site-packages\xarray\backends\api.py:721, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     714 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
#     715 backend_ds = backend.open_dataset(
#     716     filename_or_obj,
#     717     drop_variables=drop_variables,
#     718     **decoders,
#     719     **kwargs,
#     720 )
# --> 721 ds = _dataset_from_backend_dataset(
#     722     backend_ds,
#     723     filename_or_obj,
#     724     engine,
#     725     chunks,
#     726     cache,
#     727     overwrite_encoded_chunks,
#     728     inline_array,
#     729     chunked_array_type,
#     730     from_array_kwargs,
#     731     drop_variables=drop_variables,
#     732     create_default_indexes=create_default_indexes,
#     733     **decoders,
#     734     **kwargs,
#     735 )
#     736 return ds
#
# File c:\Users\Michel\AppData\Local\Programs\Python\Python313\Lib\site-packages\xarray\backends\api.py:418, in _dataset_from_backend_dataset(backend_ds, filename_or_obj, engine, chunks, cache, overwrite_encoded_chunks, inline_array, chunked_array_type, from_array_kwargs, create_default_indexes, **extra_tokens)
#     415     ds = backend_ds
#     417 if chunks is not None:
# --> 418     ds = _chunk_ds(
#     419         ds,
#     420         filename_or_obj,
#     421         engine,
#     422         chunks,
#     423         overwrite_encoded_chunks,
#     424         inline_array,
#     425         chunked_array_type,
#     426         from_array_kwargs,
#     427         **extra_tokens,
#     428     )
#     430 ds.set_close(backend_ds._close)
#     432 # Ensure source filename always stored in dataset object
#
# File c:\Users\Michel\AppData\Local\Programs\Python\Python313\Lib\site-packages\xarray\backends\api.py:352, in _chunk_ds(backend_ds, filename_or_obj, engine, chunks, overwrite_encoded_chunks, inline_array, chunked_array_type, from_array_kwargs, **extra_tokens)
#     341 def _chunk_ds(
#     342     backend_ds,
#     343     filename_or_obj,
#    (...)    350     **extra_tokens,
#     351 ):
# --> 352     chunkmanager = guess_chunkmanager(chunked_array_type)
#     354     # TODO refactor to move this dask-specific logic inside the DaskManager class
#     355     if isinstance(chunkmanager, DaskManager):
#
# File c:\Users\Michel\AppData\Local\Programs\Python\Python313\Lib\site-packages\xarray\namedarray\parallelcompat.py:116, in guess_chunkmanager(manager)
#     114 if isinstance(manager, str):
#     115     if manager not in available_chunkmanagers and manager in KNOWN_CHUNKMANAGERS:
# --> 116         raise ImportError(
#     117             f"chunk manager {manager!r} is not available."
#     118             f" Please make sure {KNOWN_CHUNKMANAGERS[manager]!r} is installed"
#     119             " and importable."
#     120         )
#     121     elif len(available_chunkmanagers) == 0:
#     122         raise ImportError(
#     123             "no chunk managers available. Try installing `dask` or another package"
#     124             " that provides a chunk manager."
#     125         )
#
# ImportError: chunk manager 'dask' is not available. Please make sure 'dask' is installed and importable.
