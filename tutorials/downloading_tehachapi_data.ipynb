# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from data.data_helpers import get_dataframe

df = get_dataframe()
print(df.to_string())
# Out:
# Skipping existing file era5_tehachapi_2018_H1.nc
# Skipping existing file era5_tehachapi_2018_H2.nc
# Skipping existing file era5_tehachapi_2019_H1.nc
# Skipping existing file era5_tehachapi_2019_H2.nc
# Skipping existing file era5_tehachapi_2020_H1.nc
# Skipping existing file era5_tehachapi_2020_H2.nc
#                           u10       v10         t2m          sp
# datetime
# 2018-01-01 00:00:00 -0.808231 -0.069685  291.890625  89925.2500
# 2018-01-01 01:00:00 -1.340298 -0.725997  290.692627  89972.2500
# 2018-01-01 02:00:00 -0.462882 -1.156458  288.544922  90036.1875
# 2018-01-01 03:00:00  0.300817 -1.009697  285.121826  90091.3125
# 2018-01-01 04:00:00  0.736362 -0.846944  283.715820  90125.1250
# 2018-01-01 05:00:00  1.050719 -0.868449  282.935059  90172.9375
# 2018-01-01 06:00:00  1.068539 -1.051906  282.375000  90223.8125
# 2018-01-01 07:00:00  1.096273 -1.133760  281.507080  90273.4375
# 2018-01-01 08:00:00  1.040055 -1.251389  281.289551  90272.9375
# ...
